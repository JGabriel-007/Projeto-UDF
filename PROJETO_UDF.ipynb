# %% [markdown]
# <a href="https://colab.research.google.com/github/JGabriel-007/Projeto-UDF/blob/main/PROJETO_UDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bibliotecas**

# %%
import sqlite3 as sql
import pandas as pd
import tkinter as tk
